# %%
# purpose is to make observations on wind power plant data
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# loading our data into the environment
data = pd.read_csv('data_files/uswtdb_full_dataset.csv')

print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73288 entries, 0 to 73287
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   case_id        73288 non-null  int64
#  1   faa_ors        69168 non-null  object
#  2   faa_asn        68724 non-null  object
#  3   usgs_pr_id     37342 non-null  float64
#  4   t_state        73288 non-null  object
#  5   t_county       73288 non-null  object
#  6   t_fips         73288 non-null  int64
#  7   p_name         73288 non-null  object
#  8   p_year         72743 non-null  float64
#  9   p_tnum         73288 non-null  int64
#  10  p_cap          70746 non-null  float64
#  11  t_manu         69589 non-null  object
#  12  t_model        69448 non-null  object
#  13  t_cap          69754 non-null  float64
#  14  t_hh           68951 non-null  float64
#  15  t_rd           69315 non-null  float64
#  16  t_rsa          69315 non-null  float64
# ...

# %%
sns.scatterplot(data=data[data['t_hh']>= 80], x='p_year', y='t_hh', hue='p_year')
plt.show()
